# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Jatin Sehgal**
# Research Intern, Lumenci

# %% [markdown]
# *I am interested in Data Science because it is concrete we can rely our decisions if we have a crisp data value telling us a story.*

# %% [markdown]
# ### I will try to calculate number of seconds in a leap year

# %%
#Total seconds in a leap year
sec=366*24*60*60
print("Total seconds in a leap year =",sec)
# Out:
# Total seconds in a leap year = 31622400

# %% [markdown]
# ### Numbered List
# 1. Greetings
# 2. Everyone
# 3. Stay
# 4. Safe
#
# ### Bulleted List
# - This
# - Is
# - My
# - Submission
#
# ### Tables
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
# | Untouched | Normal | .8 |
#
# ### ~~Strike Through~~
